# %% [markdown]
# # Clustering Neighborhoods in Toronto

# %%
import numpy as np # library to handle data in a vectorized manner

import pandas as pd # library for data analsysis
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

import json # library to handle JSON files

#!conda install -c conda-forge geopy --yes # uncomment this line if you haven't completed the Foursquare API lab
from geopy.geocoders import Nominatim # convert an address into latitude and longitude values

import requests # library to handle requests
from pandas.io.json import json_normalize # tranform JSON file into a pandas dataframe

# Matplotlib and associated plotting modules
import matplotlib.cm as cm
import matplotlib.colors as colors

# import k-means from clustering stage
from sklearn.cluster import KMeans

# !conda install -c conda-forge folium=0.5.0 --yes # uncomment this line if you haven't completed the Foursquare API lab
import folium # map rendering library

print('Libraries imported.')
# Out:
# Solving environment: done
#
# # All requested packages already installed.
#
# Libraries imported.

# %%
# The code was removed by Watson Studio for sharing.
# Out:
#    Postal Code      Borough  \
# 0          M1B  Scarborough
# 1          M1C  Scarborough
# 2          M1E  Scarborough
# 3          M1G  Scarborough
# 4          M1H  Scarborough
# 5          M1J  Scarborough
# 6          M1K  Scarborough
# 7          M1L  Scarborough
# 8          M1M  Scarborough
# 9          M1N  Scarborough
# 10         M1P  Scarborough
# 11         M1R  Scarborough
# 12         M1S  Scarborough
# 13         M1T  Scarborough
# 14         M1V  Scarborough
# 15         M1W  Scarborough
# 16         M1X  Scarborough
# 17         M2H   North York
# 18         M2J   North York
# 19         M2K   North York
#
#                                          Neighborhood   Latitude  Longitude
# 0                                       Rouge,Malvern  43.806686 -79.194353
# 1                Highland Creek,Rouge Hill,Port Union  43.784535 -79.160497
# 2                     Guildwood,Morningside,West Hill  43.763573 -79.188711
# 3                                              Woburn  43.770992 -79.216917
# 4                                           Cedarbrae  43.773136 -79.239476
# 5                                 Scarborough Village  43.744734 -79.239476
# 6           East Birchmount Park,Ionview,Kennedy Park  43.727929 -79.262029
# 7                       Clairlea,Golden Mile,Oakridge  43.711112 -79.284577
# 8       Cliffcrest,Cliffside,Scarborough Village West  43.716316 -79.239476
# 9                          Birch Cliff,Cliffside West  43.692657 -79.264848
# 10  Dorset Park,Scarborough Town Centre,Wexford He...  43.757410 -79.273304
# 11                                   Maryvale,Wexford  43.750072 -79.295849
# 12                                          Agincourt  43.794200 -79.262029
# 13              Clarks Corners,Sullivan,Tam O'Shanter  43.781638 -79.304302
# 14  Agincourt North,L'Amoreaux East,Milliken,Steel...  43.815252 -79.284577
# 15                                    L'Amoreaux West  43.799525 -79.318389
# 16                                        Upper Rouge  43.836125 -79.205636
# 17                                  Hillcrest Village  43.803762 -79.363452
# 18                         Fairview,Henry Farm,Oriole  43.778517 -79.346556
# 19                                    Bayview Village  43.786947 -79.385975

# %%
neighborhoods = data_comb[['Borough', 'Neighborhood','Latitude','Longitude']]
neighborhoods.head()
# Out:
#        Borough                          Neighborhood   Latitude  Longitude
# 0  Scarborough                         Rouge,Malvern  43.806686 -79.194353
# 1  Scarborough  Highland Creek,Rouge Hill,Port Union  43.784535 -79.160497
# 2  Scarborough       Guildwood,Morningside,West Hill  43.763573 -79.188711
# 3  Scarborough                                Woburn  43.770992 -79.216917
# 4  Scarborough                             Cedarbrae  43.773136 -79.239476

# %%
print('The dataframe has {} boroughs and {} neighborhoods.'.format(
        len(neighborhoods['Borough'].unique()),
        neighborhoods.shape[0]
    )
)
# Out:
# The dataframe has 11 boroughs and 103 neighborhoods.

# %% [markdown]
# #### Use geopy library to get the latitude and longitude values of Toronto City.
# In order to define an instance of the geocoder, we need to define a user_agent. We will name our agent <em>ny_explorer</em>, as shown below.

# %%
address = 'Toronto'

geolocator = Nominatim(user_agent="toronto_explorer")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinate of Toronto City are {}, {}.'.format(latitude, longitude))
# Out:
# The geograpical coordinate of Toronto City are 43.653963, -79.387207.

# %%
# create map of Torento using latitude and longitude values
map_torento = folium.Map(location=[latitude, longitude], zoom_start=10)

# add markers to map
for lat, lng, borough, neighborhood in zip(neighborhoods['Latitude'], neighborhoods['Longitude'], neighborhoods['Borough'], neighborhoods['Neighborhood']):
    label = '{}, {}'.format(neighborhood, borough)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_torento)  
    
map_torento
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# # Define Foursquare Credentials and Version

# %%
CLIENT_ID = '5I4CX2DSHRKH42AL3ZQCBCYF2JPFLN3WCW5Z1S2HRBDGDJWW' # your Foursquare ID
CLIENT_SECRET = '3VDDIH24LT4YKEU3OM3IMKPA3O5EKLHZHCGIX0QPPWY2KOLE' # your Foursquare Secret
VERSION = '20180605' # Foursquare API version

print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: 5I4CX2DSHRKH42AL3ZQCBCYF2JPFLN3WCW5Z1S2HRBDGDJWW
# CLIENT_SECRET:3VDDIH24LT4YKEU3OM3IMKPA3O5EKLHZHCGIX0QPPWY2KOLE

# %%
northyork_data = neighborhoods[neighborhoods['Borough'] == 'North York'].reset_index(drop=True)
northyork_data.head()
# Out:
#       Borough                Neighborhood   Latitude  Longitude
# 0  North York           Hillcrest Village  43.803762 -79.363452
# 1  North York  Fairview,Henry Farm,Oriole  43.778517 -79.346556
# 2  North York             Bayview Village  43.786947 -79.385975
# 3  North York     Silver Hills,York Mills  43.757490 -79.374714
# 4  North York      Newtonbrook,Willowdale  43.789053 -79.408493

# %%
address = 'North York'

geolocator = Nominatim(user_agent="ny_explorer")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinate of North York are {}, {}.'.format(latitude, longitude))
# Out:
# The geograpical coordinate of North York are 43.7708175, -79.4132998.

# %%
# create map of Manhattan using latitude and longitude values
map_northyork = folium.Map(location=[latitude, longitude], zoom_start=11)

# add markers to map
for lat, lng, label in zip(northyork_data['Latitude'], northyork_data['Longitude'], northyork_data['Neighborhood']):
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_northyork)  
    
map_northyork
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# # Let's explore the first neighborhood in our dataframe.
# Get the neighborhood's name.

# %%
northyork_data.loc[0, 'Neighborhood']
# Out:
# 'Hillcrest Village'

# %% [markdown]
# Get the neighborhood's latitude and longitude values.

# %%
neighborhood_latitude = northyork_data.loc[0, 'Latitude'] # neighborhood latitude value
neighborhood_longitude = northyork_data.loc[0, 'Longitude'] # neighborhood longitude value

neighborhood_name = northyork_data.loc[0, 'Neighborhood'] # neighborhood name

print('Latitude and longitude values of {} are {}, {}.'.format(neighborhood_name, 
                                                               neighborhood_latitude, 
                                                               neighborhood_longitude))
# Out:
# Latitude and longitude values of Hillcrest Village are 43.8037622, -79.3634517.

# %% [markdown]
# ## Now, let's get the top 100 venues that are in Hillcrest Village within a radius of 500 meters.
# First, let's create the GET request URL. Name your URL url.

# %%
# type your answer here
LIMIT = 100 # limit of number of venues returned by Foursquare API
radius = 500 # define radius

# create URL
url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
    CLIENT_ID, 
    CLIENT_SECRET, 
    VERSION, 
    neighborhood_latitude, 
    neighborhood_longitude, 
    radius, 
    LIMIT)

url
# Out:
# 'https://api.foursquare.com/v2/venues/explore?&client_id=5I4CX2DSHRKH42AL3ZQCBCYF2JPFLN3WCW5Z1S2HRBDGDJWW&client_secret=3VDDIH24LT4YKEU3OM3IMKPA3O5EKLHZHCGIX0QPPWY2KOLE&v=20180605&ll=43.8037622,-79.3634517&radius=500&limit=100'

# %%
results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '5ce3de95db04f52f5e877791'},
#  'response': {'groups': [{'items': [{'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4ad9dce6f964a520651b21e3-0',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/golfcourse_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d1e6941735',
#          'name': 'Golf Course',
#          'pluralName': 'Golf Courses',
#          'primary': True,
#          'shortName': 'Golf Course'}],
#        'id': '4ad9dce6f964a520651b21e3',
#        'location': {'address': '10000 Dufferin Rd',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'country': 'Canada',
#         'distance': 197,
#         'formattedAddress': ['10000 Dufferin Rd', 'Toronto ON', 'Canada'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.805454826002794,
#           'lng': -79.36418592243415}],
#         'lat': 43.805454826002794,
#         'lng': -79.36418592243415,
#         'state': 'ON'},
#        'name': "Eagle's Nest Golf Club",
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4e1fad69fa761d67106a9989-1',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/pool_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d15e941735',
#          'name': 'Pool',
#          'pluralName': 'Pools',
#          'primary': True,
#          'shortName': 'Pool'}],
#        'id': '4e1fad69fa761d67106a9989',
#        'location': {'address': '50 Francine drive',
#         'cc': 'CA',
#         'city': 'North York',
#         'country': 'Canada',
#         'crossStreet': 'Leslie',
#         'distance': 231,
#         'formattedAddress': ['50 Francine drive (Leslie)',
#          'North York ON',
#          'Canada'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.804515413699576,
#           'lng': -79.36613821581467}],
#         'lat': 43.804515413699576,
#         'lng': -79.36613821581467,
#         'state': 'ON'},
#        'name': 'AY Jackson Pool',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-5331a799498e3bfbae4a5a04-2',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/mediterranean_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d1c0941735',
#          'name': 'Mediterranean Restaurant',
#          'pluralName': 'Mediterranean Restaurants',
#          'primary': True,
#          'shortName': 'Mediterranean'}],
#        'id': '5331a799498e3bfbae4a5a04',
#        'location': {'cc': 'CA',
#         'city': 'Toronto',
#         'country': 'Canada',
#         'distance': 234,
#         'formattedAddress': ['Toronto ON', 'Canada'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.80168506227364,
#           'lng': -79.36393844569061}],
#         'lat': 43.80168506227364,
#         'lng': -79.36393844569061,
#         'state': 'ON'},
#        'name': 'Villa Madina',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4c64ca1b772bef3bfadbc2aa-3',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/dogrun_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d1e5941735',
#          'name': 'Dog Run',
#          'pluralName': 'Dog Runs',
#          'primary': True,
#          'shortName': 'Dog Run'}],
#        'id': '4c64ca1b772bef3bfadbc2aa',
#        'location': {'address': 'Aspenwood Drive',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'country': 'Canada',
#         'crossStreet': 'btwn Don Mills & Leslie',
#         'distance': 296,
#         'formattedAddress': ['Aspenwood Drive (btwn Don Mills & Leslie)',
#          'Toronto ON',
#          'Canada'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.80553928816196,
#           'lng': -79.36069456944033}],
#         'lat': 43.80553928816196,
#         'lng': -79.36069456944033,
#         'state': 'ON'},
#        'name': 'Duncan Creek Park',
#        'photos': {'count': 0, 'groups': []}}}],
#     'name': 'recommended',
#     'type': 'Recommended Places'}],
#   'headerFullLocation': 'Toronto',
#   'headerLocation': 'Toronto',
#   'headerLocationGranularity': 'city',
#   'suggestedBounds': {'ne': {'lat': 43.808262204500004,
#     'lng': -79.3572281853783},
#    'sw': {'lat': 43.7992621955, 'lng': -79.3696752146217}},
#   'totalResults': 4}}

# %%
# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# %%
venues = results['response']['groups'][0]['items']
    
nearby_venues = json_normalize(venues) # flatten JSON

# filter columns
filtered_columns = ['venue.name', 'venue.categories', 'venue.location.lat', 'venue.location.lng']
nearby_venues =nearby_venues.loc[:, filtered_columns]

# filter the category for each row
nearby_venues['venue.categories'] = nearby_venues.apply(get_category_type, axis=1)

# clean columns
nearby_venues.columns = [col.split(".")[-1] for col in nearby_venues.columns]

nearby_venues.head()
# Out:
#                      name                categories        lat        lng
# 0  Eagle's Nest Golf Club               Golf Course  43.805455 -79.364186
# 1         AY Jackson Pool                      Pool  43.804515 -79.366138
# 2            Villa Madina  Mediterranean Restaurant  43.801685 -79.363938
# 3       Duncan Creek Park                   Dog Run  43.805539 -79.360695

# %%
print('{} venues were returned by Foursquare.'.format(nearby_venues.shape[0]))
# Out:
# 4 venues were returned by Foursquare.

# %% [markdown]
# # Explore Neighborhoods in North York
# ## Let's create a function to repeat the same process to all the neighborhoods in North York

# %%
def getNearbyVenues(names, latitudes, longitudes, radius=500):
    
    venues_list=[]
    for name, lat, lng in zip(names, latitudes, longitudes):
        print(name)
            
        # create the API request URL
        url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            lng, 
            radius, 
            LIMIT)
            
        # make the GET request
        results = requests.get(url).json()["response"]['groups'][0]['items']
        
        # return only relevant information for each nearby venue
        venues_list.append([(
            name, 
            lat, 
            lng, 
            v['venue']['name'], 
            v['venue']['location']['lat'], 
            v['venue']['location']['lng'],  
            v['venue']['categories'][0]['name']) for v in results])

    nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
    nearby_venues.columns = ['Neighborhood', 
                  'Neighborhood Latitude', 
                  'Neighborhood Longitude', 
                  'Venue', 
                  'Venue Latitude', 
                  'Venue Longitude', 
                  'Venue Category']
    
    return(nearby_venues)

# %%
northyork_venues = getNearbyVenues(names=northyork_data['Neighborhood'],
                                   latitudes=northyork_data['Latitude'],
                                   longitudes=northyork_data['Longitude']
                                  )
# Out:
# Hillcrest Village
# Fairview,Henry Farm,Oriole
# Bayview Village
# Silver Hills,York Mills
# Newtonbrook,Willowdale
# Willowdale South
# York Mills West
# Willowdale West
# Parkwoods
# Don Mills North
# Flemingdon Park,Don Mills South
# Bathurst Manor,Downsview North,Wilson Heights
# Northwood Park,York University
# CFB Toronto,Downsview East
# Downsview West
# Downsview Central
# Downsview Northwest
# Victoria Village
# Bedford Park,Lawrence Manor East
# Lawrence Heights,Lawrence Manor
# Glencairn
# Downsview,North Park,Upwood Park
# Humber Summit
# Emery,Humberlea

# %%
print(northyork_venues.shape)
northyork_venues.head()
# Out:
# (243, 7)
#                  Neighborhood  Neighborhood Latitude  Neighborhood Longitude  \
# 0           Hillcrest Village              43.803762              -79.363452
# 1           Hillcrest Village              43.803762              -79.363452
# 2           Hillcrest Village              43.803762              -79.363452
# 3           Hillcrest Village              43.803762              -79.363452
# 4  Fairview,Henry Farm,Oriole              43.778517              -79.346556
#
#                     Venue  Venue Latitude  Venue Longitude  \
# 0  Eagle's Nest Golf Club       43.805455       -79.364186
# 1         AY Jackson Pool       43.804515       -79.366138
# 2            Villa Madina       43.801685       -79.363938
# 3       Duncan Creek Park       43.805539       -79.360695
# 4          The LEGO Store       43.778207       -79.343483
#
#              Venue Category
# 0               Golf Course
# 1                      Pool
# 2  Mediterranean Restaurant
# 3                   Dog Run
# 4          Toy / Game Store

# %% [markdown]
# Let's check how many venues were returned for each neighborhood

# %%
northyork_venues.groupby('Neighborhood').count()
# Out:
#                                                Neighborhood Latitude  \
# Neighborhood
# Bathurst Manor,Downsview North,Wilson Heights                     18
# Bayview Village                                                    4
# Bedford Park,Lawrence Manor East                                  22
# CFB Toronto,Downsview East                                         3
# Don Mills North                                                    6
# Downsview Central                                                  2
# Downsview Northwest                                                4
# Downsview West                                                     5
# Downsview,North Park,Upwood Park                                   4
# Emery,Humberlea                                                    1
# Fairview,Henry Farm,Oriole                                        72
# Flemingdon Park,Don Mills South                                   22
# Glencairn                                                          5
# Hillcrest Village                                                  4
# Humber Summit                                                      2
# Lawrence Heights,Lawrence Manor                                   13
# Northwood Park,York University                                     4
# Parkwoods                                                          3
# Silver Hills,York Mills                                            1
# Victoria Village                                                   5
# Willowdale South                                                  35
# Willowdale West                                                    5
# York Mills West                                                    3
#
#                                                Neighborhood Longitude  Venue  \
# Neighborhood
# Bathurst Manor,Downsview North,Wilson Heights                      18     18
# Bayview Village                                                     4      4
# Bedford Park,Lawrence Manor East                                   22     22
# CFB Toronto,Downsview East                                          3      3
# Don Mills North                                                     6      6
# Downsview Central                                                   2      2
# Downsview Northwest                                                 4      4
# Downsview West                                                      5      5
# Downsview,North Park,Upwood Park                                    4      4
# Emery,Humberlea                                                     1      1
# Fairview,Henry Farm,Oriole                                         72     72
# Flemingdon Park,Don Mills South                                    22     22
# Glencairn                                                           5      5
# Hillcrest Village                                                   4      4
# Humber Summit                                                       2      2
# Lawrence Heights,Lawrence Manor                                    13     13
# Northwood Park,York University                                      4      4
# Parkwoods                                                           3      3
# Silver Hills,York Mills                                             1      1
# Victoria Village                                                    5      5
# Willowdale South                                                   35     35
# Willowdale West                                                     5      5
# York Mills West                                                     3      3
#
#                                                Venue Latitude  \
# Neighborhood
# Bathurst Manor,Downsview North,Wilson Heights              18
# Bayview Village                                             4
# Bedford Park,Lawrence Manor East                           22
# CFB Toronto,Downsview East                                  3
# Don Mills North                                             6
# Downsview Central                                           2
# Downsview Northwest                                         4
# Downsview West                                              5
# Downsview,North Park,Upwood Park                            4
# Emery,Humberlea                                             1
# Fairview,Henry Farm,Oriole                                 72
# Flemingdon Park,Don Mills South                            22
# Glencairn                                                   5
# Hillcrest Village                                           4
# Humber Summit                                               2
# Lawrence Heights,Lawrence Manor                            13
# Northwood Park,York University                              4
# Parkwoods                                                   3
# Silver Hills,York Mills                                     1
# Victoria Village                                            5
# Willowdale South                                           35
# Willowdale West                                             5
# York Mills West                                             3
#
#                                                Venue Longitude  Venue Category
# Neighborhood
# Bathurst Manor,Downsview North,Wilson Heights               18              18
# Bayview Village                                              4               4
# Bedford Park,Lawrence Manor East                            22              22
# CFB Toronto,Downsview East                                   3               3
# Don Mills North                                              6               6
# Downsview Central                                            2               2
# Downsview Northwest                                          4               4
# Downsview West                                               5               5
# Downsview,North Park,Upwood Park                             4               4
# Emery,Humberlea                                              1               1
# Fairview,Henry Farm,Oriole                                  72              72
# Flemingdon Park,Don Mills South                             22              22
# Glencairn                                                    5               5
# Hillcrest Village                                            4               4
# Humber Summit                                                2               2
# Lawrence Heights,Lawrence Manor                             13              13
# Northwood Park,York University                               4               4
# Parkwoods                                                    3               3
# Silver Hills,York Mills                                      1               1
# Victoria Village                                             5               5
# Willowdale South                                            35              35
# Willowdale West                                              5               5
# York Mills West                                              3               3

# %% [markdown]
# ## Let's find out how many unique categories can be curated from all the returned venues

# %%
print('There are {} uniques categories.'.format(len(northyork_venues['Venue Category'].unique())))
# Out:
# There are 109 uniques categories.

# %% [markdown]
# # 3. Analyze Each Neighborhood

# %%
# one hot encoding
northyork_onehot = pd.get_dummies(northyork_venues[['Venue Category']], prefix="", prefix_sep="")

# add neighborhood column back to dataframe
northyork_onehot['Neighborhood'] = northyork_venues['Neighborhood'] 

# move neighborhood column to the first column
fixed_columns = [northyork_onehot.columns[-1]] + list(northyork_onehot.columns[:-1])
northyork_onehot = northyork_onehot[fixed_columns]

northyork_grouped = northyork_onehot.groupby('Neighborhood').mean().reset_index()

num_top_venues = 5

for hood in northyork_grouped['Neighborhood']:
    print("----"+hood+"----")
    temp = northyork_grouped[northyork_grouped['Neighborhood'] == hood].T.reset_index()
    temp.columns = ['venue','freq']
    temp = temp.iloc[1:]
    temp['freq'] = temp['freq'].astype(float)
    temp = temp.round({'freq': 2})
    print(temp.sort_values('freq', ascending=False).reset_index(drop=True).head(num_top_venues))
    print('\n')
# Out:
# ----Bathurst Manor,Downsview North,Wilson Heights----
#                 venue  freq
# 0         Coffee Shop  0.11
# 1  Frozen Yogurt Shop  0.06
# 2         Bridal Shop  0.06
# 3         Pizza Place  0.06
# 4       Deli / Bodega  0.06
#
#
# ----Bayview Village----
#                  venue  freq
# 0   Chinese Restaurant  0.25
# 1                 Bank  0.25
# 2  Japanese Restaurant  0.25
# 3                 Café  0.25
# 4    Accessories Store  0.00
#
#
# ----Bedford Park,Lawrence Manor East----
#                   venue  freq
# 0  Fast Food Restaurant  0.09
# 1    Italian Restaurant  0.09
# 2           Coffee Shop  0.09
# 3      Sushi Restaurant  0.05
# 4                  Café  0.05
#
#
# ----CFB Toronto,Downsview East----
#          venue  freq
# 0      Airport  0.33
# 1         Park  0.33
# 2  Snack Place  0.33
# 3        Plaza  0.00
# 4     Pharmacy  0.00
#
#
# ----Don Mills North----
#                   venue  freq
# 0  Gym / Fitness Center  0.17
# 1   Japanese Restaurant  0.17
# 2  Caribbean Restaurant  0.17
# 3        Baseball Field  0.17
# 4      Basketball Court  0.17
#
#
# ----Downsview Central----
#                venue  freq
# 0     Baseball Field   0.5
# 1         Food Truck   0.5
# 2  Accessories Store   0.0
# 3     Massage Studio   0.0
# 4        Pizza Place   0.0
#
#
# ----Downsview Northwest----
#                 venue  freq
# 0       Grocery Store  0.25
# 1  Athletics & Sports  0.25
# 2      Discount Store  0.25
# 3        Liquor Store  0.25
# 4   Accessories Store  0.00
#
#
# ----Downsview West----
#            venue  freq
# 0  Grocery Store   0.2
# 1           Park   0.2
# 2           Bank   0.2
# 3  Moving Target   0.2
# 4  Shopping Mall   0.2
#
#
# ----Downsview,North Park,Upwood Park----
#                         venue  freq
# 0              Massage Studio  0.25
# 1                      Bakery  0.25
# 2                        Park  0.25
# 3  Construction & Landscaping  0.25
# 4    Mediterranean Restaurant  0.00
#
#
# ----Emery,Humberlea----
#                venue  freq
# 0     Baseball Field   1.0
# 1  Accessories Store   0.0
# 2     Massage Studio   0.0
# 3        Pizza Place   0.0
# 4           Pharmacy   0.0
#
#
# ----Fairview,Henry Farm,Oriole----
#                   venue  freq
# 0        Clothing Store  0.12
# 1  Fast Food Restaurant  0.07
# 2           Coffee Shop  0.07
# 3            Shoe Store  0.03
# 4            Food Court  0.03
#
#
# ----Flemingdon Park,Don Mills South----
#               venue  freq
# 0        Beer Store  0.09
# 1  Asian Restaurant  0.09
# 2       Coffee Shop  0.09
# 3               Gym  0.09
# 4     Grocery Store  0.09
#
#
# ----Glencairn----
#                  venue  freq
# 0          Pizza Place   0.2
# 1                  Pub   0.2
# 2     Asian Restaurant   0.2
# 3                 Park   0.2
# 4  Japanese Restaurant   0.2
#
#
# ----Hillcrest Village----
#                       venue  freq
# 0                      Pool  0.25
# 1               Golf Course  0.25
# 2                   Dog Run  0.25
# 3  Mediterranean Restaurant  0.25
# 4            Massage Studio  0.00
#
#
# ----Humber Summit----
#                  venue  freq
# 0          Pizza Place   0.5
# 1  Empanada Restaurant   0.5
# 2       Massage Studio   0.0
# 3             Pharmacy   0.0
# 4            Pet Store   0.0
#
#
# ----Lawrence Heights,Lawrence Manor----
#                     venue  freq
# 0          Clothing Store  0.23
# 1  Furniture / Home Store  0.23
# 2             Coffee Shop  0.08
# 3             Event Space  0.08
# 4      Miscellaneous Shop  0.08
#
#
# ----Northwood Park,York University----
#                          venue  freq
# 0               Massage Studio  0.25
# 1                  Coffee Shop  0.25
# 2                          Bar  0.25
# 3  Eastern European Restaurant  0.25
# 4     Mediterranean Restaurant  0.00
#
#
# ----Parkwoods----
#                   venue  freq
# 0     Food & Drink Shop  0.33
# 1  Fast Food Restaurant  0.33
# 2                  Park  0.33
# 3              Pharmacy  0.00
# 4             Pet Store  0.00
#
#
# ----Silver Hills,York Mills----
#                venue  freq
# 0          Cafeteria   1.0
# 1  Accessories Store   0.0
# 2               Pool   0.0
# 3        Pizza Place   0.0
# 4           Pharmacy   0.0
#
#
# ----Victoria Village----
#                    venue  freq
# 0  Portuguese Restaurant   0.2
# 1            Coffee Shop   0.2
# 2           Intersection   0.2
# 3            Pizza Place   0.2
# 4           Hockey Arena   0.2
#
#
# ----Willowdale South----
#                  venue  freq
# 0          Coffee Shop  0.09
# 1     Ramen Restaurant  0.09
# 2       Sandwich Place  0.06
# 3                 Café  0.06
# 4  Japanese Restaurant  0.06
#
#
# ----Willowdale West----
#             venue  freq
# 0     Pizza Place   0.2
# 1     Coffee Shop   0.2
# 2        Pharmacy   0.2
# 3  Discount Store   0.2
# 4         Butcher   0.2
#
#
# ----York Mills West----
#                       venue  freq
# 0         Convenience Store  0.33
# 1                      Park  0.33
# 2                      Bank  0.33
# 3  Mediterranean Restaurant  0.00
# 4                     Plaza  0.00

# %% [markdown]
# ### Let's put that into a pandas dataframe
# First, let's write a function to sort the venues in descending order.

# %%
def return_most_common_venues(row, num_top_venues):
    row_categories = row.iloc[1:]
    row_categories_sorted = row_categories.sort_values(ascending=False)
    
    return row_categories_sorted.index.values[0:num_top_venues]

# %%
num_top_venues = 10

indicators = ['st', 'nd', 'rd']

# create columns according to number of top venues
columns = ['Neighborhood']
for ind in np.arange(num_top_venues):
    try:
        columns.append('{}{} Most Common Venue'.format(ind+1, indicators[ind]))
    except:
        columns.append('{}th Most Common Venue'.format(ind+1))

# create a new dataframe
neighborhoods_venues_sorted = pd.DataFrame(columns=columns)
neighborhoods_venues_sorted['Neighborhood'] = northyork_grouped['Neighborhood']

for ind in np.arange(northyork_grouped.shape[0]):
    neighborhoods_venues_sorted.iloc[ind, 1:] = return_most_common_venues(northyork_grouped.iloc[ind, :], num_top_venues)

neighborhoods_venues_sorted.head()
# Out:
#                                     Neighborhood 1st Most Common Venue  \
# 0  Bathurst Manor,Downsview North,Wilson Heights           Coffee Shop
# 1                                Bayview Village    Chinese Restaurant
# 2               Bedford Park,Lawrence Manor East    Italian Restaurant
# 3                     CFB Toronto,Downsview East               Airport
# 4                                Don Mills North  Gym / Fitness Center
#
#   2nd Most Common Venue      3rd Most Common Venue 4th Most Common Venue  \
# 0  Fast Food Restaurant  Middle Eastern Restaurant           Pizza Place
# 1                  Café                       Bank   Japanese Restaurant
# 2           Coffee Shop       Fast Food Restaurant     Indian Restaurant
# 3                  Park                Snack Place           Yoga Studio
# 4  Caribbean Restaurant                       Café        Baseball Field
#
#   5th Most Common Venue 6th Most Common Venue 7th Most Common Venue  \
# 0         Deli / Bodega                 Diner            Restaurant
# 1           Yoga Studio   Empanada Restaurant        Cosmetics Shop
# 2              Pharmacy           Pizza Place                  Café
# 3     Electronics Store     Convenience Store        Cosmetics Shop
# 4      Basketball Court   Japanese Restaurant           Event Space
#
#   8th Most Common Venue 9th Most Common Venue 10th Most Common Venue
# 0        Sandwich Place           Bridal Shop          Shopping Mall
# 1         Deli / Bodega      Department Store     Dim Sum Restaurant
# 2          Liquor Store               Butcher                    Pub
# 3         Deli / Bodega      Department Store     Dim Sum Restaurant
# 4         Deli / Bodega      Department Store     Dim Sum Restaurant

# %% [markdown]
# # 4. Cluster Neighborhoods
# Run k-means to cluster the neighborhood into 5 clusters.

# %%
# set number of clusters
kclusters = 5

northyork_grouped_clustering = northyork_grouped.drop('Neighborhood', 1)

# run k-means clustering
kmeans = KMeans(n_clusters=kclusters, random_state=0).fit(northyork_grouped_clustering)

# check cluster labels generated for each row in the dataframe
kmeans.labels_[0:10]
# Out:
# array([0, 0, 0, 0, 0, 2, 0, 0, 0, 1], dtype=int32)

# %%
# add clustering labels
neighborhoods_venues_sorted.insert(0, 'Cluster Labels', kmeans.labels_)

northyork_merged = northyork_data

# merge toronto_grouped with toronto_data to add latitude/longitude for each neighborhood
northyork_merged = northyork_merged.join(neighborhoods_venues_sorted.set_index('Neighborhood'), on='Neighborhood')

northyork_merged.head() # check the last columns!
# Out:
#       Borough                Neighborhood   Latitude  Longitude  \
# 0  North York           Hillcrest Village  43.803762 -79.363452
# 1  North York  Fairview,Henry Farm,Oriole  43.778517 -79.346556
# 2  North York             Bayview Village  43.786947 -79.385975
# 3  North York     Silver Hills,York Mills  43.757490 -79.374714
# 4  North York      Newtonbrook,Willowdale  43.789053 -79.408493
#
#    Cluster Labels 1st Most Common Venue 2nd Most Common Venue  \
# 0             0.0           Golf Course                  Pool
# 1             0.0        Clothing Store  Fast Food Restaurant
# 2             0.0    Chinese Restaurant                  Café
# 3             4.0             Cafeteria           Yoga Studio
# 4             NaN                   NaN                   NaN
#
#       3rd Most Common Venue 4th Most Common Venue 5th Most Common Venue  \
# 0  Mediterranean Restaurant               Dog Run           Yoga Studio
# 1               Coffee Shop             Gift Shop            Food Court
# 2                      Bank   Japanese Restaurant           Yoga Studio
# 3       Empanada Restaurant     Convenience Store        Cosmetics Shop
# 4                       NaN                   NaN                   NaN
#
#          6th Most Common Venue       7th Most Common Venue  \
# 0  Eastern European Restaurant  Construction & Landscaping
# 1                   Restaurant                      Bakery
# 2          Empanada Restaurant              Cosmetics Shop
# 3                Deli / Bodega            Department Store
# 4                          NaN                         NaN
#
#   8th Most Common Venue 9th Most Common Venue 10th Most Common Venue
# 0     Convenience Store        Cosmetics Shop          Deli / Bodega
# 1            Kids Store   Japanese Restaurant             Shoe Store
# 2         Deli / Bodega      Department Store     Dim Sum Restaurant
# 3    Dim Sum Restaurant                 Diner         Discount Store
# 4                   NaN                   NaN                    NaN

# %% [markdown]
# # 5. Examine Clusters
# Now, you can examine each cluster and determine the discriminating venue categories that distinguish each cluster. Based on the defining categories, you can then assign a name to each cluster. I will leave this exercise to you.

# %% [markdown]
# ## Cluster 1

# %%
northyork_merged.loc[northyork_merged['Cluster Labels'] == 0, northyork_merged.columns[[1] + list(range(5, northyork_merged.shape[1]))]]
# Out:
#                                      Neighborhood       1st Most Common Venue  \
# 0                               Hillcrest Village                 Golf Course
# 1                      Fairview,Henry Farm,Oriole              Clothing Store
# 2                                 Bayview Village          Chinese Restaurant
# 5                                Willowdale South                 Coffee Shop
# 6                                 York Mills West           Convenience Store
# 7                                 Willowdale West                 Coffee Shop
# 8                                       Parkwoods                        Park
# 9                                 Don Mills North        Gym / Fitness Center
# 10                Flemingdon Park,Don Mills South               Grocery Store
# 11  Bathurst Manor,Downsview North,Wilson Heights                 Coffee Shop
# 12                 Northwood Park,York University                 Coffee Shop
# 13                     CFB Toronto,Downsview East                     Airport
# 14                                 Downsview West               Grocery Store
# 16                            Downsview Northwest               Grocery Store
# 17                               Victoria Village                 Pizza Place
# 18               Bedford Park,Lawrence Manor East          Italian Restaurant
# 19                Lawrence Heights,Lawrence Manor      Furniture / Home Store
# 20                                      Glencairn                 Pizza Place
# 21               Downsview,North Park,Upwood Park  Construction & Landscaping
#
#     2nd Most Common Venue        3rd Most Common Venue 4th Most Common Venue  \
# 0                    Pool     Mediterranean Restaurant               Dog Run
# 1    Fast Food Restaurant                  Coffee Shop             Gift Shop
# 2                    Café                         Bank   Japanese Restaurant
# 5        Ramen Restaurant               Sandwich Place      Sushi Restaurant
# 6                    Park                         Bank           Yoga Studio
# 7             Pizza Place                      Butcher        Discount Store
# 8       Food & Drink Shop         Fast Food Restaurant           Yoga Studio
# 9    Caribbean Restaurant                         Café        Baseball Field
# 10                    Gym                  Coffee Shop      Asian Restaurant
# 11   Fast Food Restaurant    Middle Eastern Restaurant           Pizza Place
# 12                    Bar  Eastern European Restaurant        Massage Studio
# 13                   Park                  Snack Place           Yoga Studio
# 14                   Park                Moving Target                  Bank
# 16     Athletics & Sports               Discount Store          Liquor Store
# 17  Portuguese Restaurant                 Hockey Arena          Intersection
# 18            Coffee Shop         Fast Food Restaurant     Indian Restaurant
# 19         Clothing Store            Accessories Store              Boutique
# 20                   Park             Asian Restaurant                   Pub
# 21                   Park                       Bakery        Massage Studio
#
#    5th Most Common Venue        6th Most Common Venue  \
# 0            Yoga Studio  Eastern European Restaurant
# 1             Food Court                   Restaurant
# 2            Yoga Studio          Empanada Restaurant
# 5                   Café          Japanese Restaurant
# 6    Empanada Restaurant               Cosmetics Shop
# 7               Pharmacy       Furniture / Home Store
# 8      Electronics Store            Convenience Store
# 9       Basketball Court          Japanese Restaurant
# 10            Beer Store               Clothing Store
# 11         Deli / Bodega                        Diner
# 12   Empanada Restaurant            Convenience Store
# 13     Electronics Store            Convenience Store
# 14         Shopping Mall            Electronics Store
# 16             Gift Shop        General Entertainment
# 17           Coffee Shop  Eastern European Restaurant
# 18              Pharmacy                  Pizza Place
# 19         Women's Store                  Event Space
# 20   Japanese Restaurant  Eastern European Restaurant
# 21     Electronics Store            Convenience Store
#
#          7th Most Common Venue    8th Most Common Venue  \
# 0   Construction & Landscaping        Convenience Store
# 1                       Bakery               Kids Store
# 2               Cosmetics Shop            Deli / Bodega
# 5                   Restaurant          Bubble Tea Shop
# 6                Deli / Bodega         Department Store
# 7                    Gift Shop  Comfort Food Restaurant
# 8               Cosmetics Shop            Deli / Bodega
# 9                  Event Space            Deli / Bodega
# 10         Sporting Goods Shop       Chinese Restaurant
# 11                  Restaurant           Sandwich Place
# 12              Cosmetics Shop            Deli / Bodega
# 13              Cosmetics Shop            Deli / Bodega
# 14           Convenience Store           Cosmetics Shop
# 16           Convenience Store           Cosmetics Shop
# 17  Construction & Landscaping        Convenience Store
# 18                        Café             Liquor Store
# 19          Miscellaneous Shop              Coffee Shop
# 20  Construction & Landscaping        Convenience Store
# 21              Cosmetics Shop            Deli / Bodega
#
#          9th Most Common Venue 10th Most Common Venue
# 0               Cosmetics Shop          Deli / Bodega
# 1          Japanese Restaurant             Shoe Store
# 2             Department Store     Dim Sum Restaurant
# 5        Indonesian Restaurant            Pizza Place
# 6           Dim Sum Restaurant                  Diner
# 7   Construction & Landscaping      Convenience Store
# 8             Department Store     Dim Sum Restaurant
# 9             Department Store     Dim Sum Restaurant
# 10          Dim Sum Restaurant         Discount Store
# 11                 Bridal Shop          Shopping Mall
# 12            Department Store     Dim Sum Restaurant
# 13            Department Store     Dim Sum Restaurant
# 14               Deli / Bodega       Department Store
# 16               Deli / Bodega       Department Store
# 17              Cosmetics Shop          Deli / Bodega
# 18                     Butcher                    Pub
# 19       Vietnamese Restaurant                 Bakery
# 20              Cosmetics Shop          Deli / Bodega
# 21            Department Store     Dim Sum Restaurant

# %% [markdown]
# ## Cluster 2

# %%
northyork_merged.loc[northyork_merged['Cluster Labels'] == 1, northyork_merged.columns[[1] + list(range(5, northyork_merged.shape[1]))]]
# Out:
#        Neighborhood 1st Most Common Venue 2nd Most Common Venue  \
# 23  Emery,Humberlea        Baseball Field           Yoga Studio
#
#    3rd Most Common Venue 4th Most Common Venue 5th Most Common Venue  \
# 23           Event Space     Convenience Store        Cosmetics Shop
#
#    6th Most Common Venue 7th Most Common Venue 8th Most Common Venue  \
# 23         Deli / Bodega      Department Store    Dim Sum Restaurant
#
#    9th Most Common Venue 10th Most Common Venue
# 23                 Diner         Discount Store

# %% [markdown]
# ## Cluster 3

# %%
northyork_merged.loc[northyork_merged['Cluster Labels'] == 3, northyork_merged.columns[[1] + list(range(5, northyork_merged.shape[1]))]]
# Out:
#      Neighborhood 1st Most Common Venue 2nd Most Common Venue  \
# 22  Humber Summit   Empanada Restaurant           Pizza Place
#
#    3rd Most Common Venue       4th Most Common Venue 5th Most Common Venue  \
# 22           Yoga Studio  Construction & Landscaping     Convenience Store
#
#    6th Most Common Venue 7th Most Common Venue 8th Most Common Venue  \
# 22        Cosmetics Shop         Deli / Bodega      Department Store
#
#    9th Most Common Venue 10th Most Common Venue
# 22    Dim Sum Restaurant                  Diner

# %% [markdown]
# ## Cluster 4

# %%
northyork_merged.loc[northyork_merged['Cluster Labels'] == 4, northyork_merged.columns[[1] + list(range(5, northyork_merged.shape[1]))]]
# Out:
#               Neighborhood 1st Most Common Venue 2nd Most Common Venue  \
# 3  Silver Hills,York Mills             Cafeteria           Yoga Studio
#
#   3rd Most Common Venue 4th Most Common Venue 5th Most Common Venue  \
# 3   Empanada Restaurant     Convenience Store        Cosmetics Shop
#
#   6th Most Common Venue 7th Most Common Venue 8th Most Common Venue  \
# 3         Deli / Bodega      Department Store    Dim Sum Restaurant
#
#   9th Most Common Venue 10th Most Common Venue
# 3                 Diner         Discount Store

# %% [markdown]
# # Cluster 5

# %%
northyork_merged.loc[northyork_merged['Cluster Labels'] == 5, northyork_merged.columns[[1] + list(range(5, northyork_merged.shape[1]))]]
# Out:
# Empty DataFrame
# Columns: [Neighborhood, 1st Most Common Venue, 2nd Most Common Venue, 3rd Most Common Venue, 4th Most Common Venue, 5th Most Common Venue, 6th Most Common Venue, 7th Most Common Venue, 8th Most Common Venue, 9th Most Common Venue, 10th Most Common Venue]
# Index: []
